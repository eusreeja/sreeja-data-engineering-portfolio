# %%
1. Dataset Overview

# %% [markdown]
# 2. Variant Distribution

# %% [markdown]
# 3. Disease Distribution

# %% [markdown]
# 4. Gene Frequency

# %% [markdown]
# 5. Chromosome Analysis

# %% [markdown]
# 6. Disease Similarity Exploration
